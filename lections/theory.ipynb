# %% [markdown]
# # Numpy methods

# %% [markdown]
# ![image.png](attachment:38fa6860-a891-4b1a-9396-91a2ddf34885.png)

# %% [markdown]
# # OpenCV methods

# %% [markdown]
# **Загрузка и сохранение:**
# * `
# cv2.imread()`
# – загрузка изображения
# * `
# cv2.imwrite()`
# – сохранение изображения
# * `
# cv2.VideoCapture()`
# – захват видео/камеры
# * `
# cap.read()`
# – чтение кадра
# * `
# cap.release()`
# – освобождение камеры
# **Отображение:**
# * `
# cv2.imshow()`
# – показать изображение
# * `
# cv2.waitKey()`
# – ожидание нажатия клавиши
# * `
# cv2.destroyAllWindows()`
# – закрытие окон
# ---
# ### Цветовые преобразования
# * `
# cv2.cvtColor()`
# * `
# cv2.COLOR
# _
# * `
# cv2.COLOR
# _
# * `
# cv2.COLOR
# _
# – преобразование цветового пространства
# BGR2GRAY`
# BGR2RGB`
# BGR2HSV`
# – BGR → Grayscale
# – BGR → RGB
# – BGR → HSV
# ---
# ### Геометрические операции
# * `
# cv2.resize()`
# – изменение размера изображения
# * `
# cv2.getRotationMatrix2D()`
# – матрица поворота
# * `
# cv2.warpAffine()`
# – аффинное преобразование
# * `
# cv2.getPerspectiveTransform()`
# – вычисление матрицы гомографии
# * `
# cv2.warpPerspective()`
# – перспективное преобразование
# * `img[y1:y2, x1:x2]`
# – обрезка (crop)
# ### Размытие и фильтрация
# * `
# cv2.GaussianBlur()`
# – гауссово размытие
# * `
# cv2.medianBlur()`
# – медианное размытие
# * `
# cv2.bilateralFilter()`
# – билинейная фильтрация
# * `
# cv2.filter2D()`
# – произвольная свёртка
# ---
# ### Пороговая обработка (бинаризация)
# * `
# cv2.threshold()`
# * `
# cv2.THRESH
# BINARY`
# _
# * `
# cv2.THRESH
# OTSU`
# _
# * `
# cv2.adaptiveThreshold()`
# – глобальная бинаризация
# – бинарный порог
# – метод Отсу
# – адаптивная бинаризация
# ---
# ### Морфологические операции
# * `
# cv2.getStructuringElement()`
# – создание ядра
# * `
# cv2.erode()`
# – эрозия
# * `
# cv2.dilate()`
# – дилатация
# * `
# cv2.morphologyEx()`
# – расширенные операции
# * `
# cv2.MORPH
# OPEN`
# _
# – открытие
# * `
# cv2.MORPH
# CLOSE`
# _
# – закрытие
# * `
# cv2.MORPH
# TOPHAT`
# _
# – Top Hat
# * `
# cv2.MORPH
# BLACKHAT`
# – Black Hat
# ### Поиск границ и контуров
# * `
# cv2.Canny()`
# – детектор границ
# * `
# cv2.findContours()`
# – поиск контуров
# * `
# cv2.drawContours()`
# – отрисовка контуров
# * `
# cv2.boundingRect()`
# – ограничивающий прямоугольник
# * `
# cv2.minAreaRect()`
# – минимальный повёрнутый прямоугольник
# * `
# cv2.contourArea()`
# – площадь контура
# * `
# cv2.arcLength()`
# – периметр контура
# * `
# cv2.approxPolyDP()`
# – аппроксимация контура
# ---
# ### Логические операции (маски)
# * `
# cv2.bitwise
# _
# * `
# cv2.bitwise
# _
# * `
# cv2.bitwise
# _
# and()`
# or()`
# xor()`
# not()`
# – логическое AND
# – логическое OR
# – XOR
# * `
# cv2.bitwise
# _
# * `
# mask=
# `
# – инверсия
# – применение маски
# ### Преобразование Хафа
# * `
# cv2.HoughLines()`
# * `
# cv2.HoughLinesP()`
# * `
# cv2.HoughCircles()`
# – поиск линий
# – вероятностный Хаф
# – поиск окружностей
# ---
# ### Выделение признаков
# * `
# cv2.ORB
# _
# create()`
# – ORB признаки
# * `
# orb.detectAndCompute()`
# – ключевые точки и дескрипторы
# * `
# cv2.BFMatcher()`
# – сопоставление дескрипторов
# ---
# ### Рисование примитивов
# * `
# cv2.rectangle()`
# – прямоугольник
# * `
# cv2.circle()`
# – окружность
# * `
# cv2.line()`
# – линия
# * `
# cv2.putText()`
# – текст на изображении
